# %%
import pandas as pd 
  
# making data frame from csv file 
data = pd.read_csv("E:\\Downloads\\nba.csv", index_col ="Name",skipinitialspace=True ) 
  
print(pd.DataFrame(data))

# dropping passed columns 
data.drop(["Team", "Weight"], axis = 1, inplace = True) 
  
# display 
print(data)
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
# Conversion function in pandas
#converting from Different Different DataType
# python is a great language for doing data analysis primarily because
# of the fantastic ecosystem of data-centric python packages
# Pandas is one of those packages and make data analyzing and importing much easier
data[:10]
# Out:
#                Number Position   Age Height            College      Salary
# Name
# Avery Bradley     0.0       PG  25.0    6-2              Texas   7730337.0
# Jae Crowder      99.0       SF  25.0    6-6          Marquette   6796117.0
# John Holland     30.0       SG  27.0    6-5  Boston University         NaN
# R.J. Hunter      28.0       SG  22.0    6-5      Georgia State   1148640.0
# Jonas Jerebko     8.0       PF  29.0   6-10                NaN   5000000.0
# Amir Johnson     90.0       PF  29.0    6-9                NaN  12000000.0
# Jordan Mickey    55.0       PF  21.0    6-8                LSU   1170960.0
# Kelly Olynyk     41.0        C  25.0    7-0            Gonzaga   2165160.0
# Terry Rozier     12.0       PG  22.0    6-2         Louisville   1824360.0
# Marcus Smart     36.0       PG  22.0    6-4     Oklahoma State   3431040.0

# %%
# in this data there is some NaN value
data.dropna(inplace =True)

# %%
data
# Out:
#                Number Position   Age Height        College     Salary
# Name
# Avery Bradley     0.0       PG  25.0    6-2          Texas  7730337.0
# Jae Crowder      99.0       SF  25.0    6-6      Marquette  6796117.0
# R.J. Hunter      28.0       SG  22.0    6-5  Georgia State  1148640.0
# Jordan Mickey    55.0       PF  21.0    6-8            LSU  1170960.0
# Kelly Olynyk     41.0        C  25.0    7-0        Gonzaga  2165160.0
# ...               ...      ...   ...    ...            ...        ...
# Rodney Hood       5.0       SG  23.0    6-8           Duke  1348440.0
# Chris Johnson    23.0       SF  26.0    6-6         Dayton   981348.0
# Trey Lyles       41.0       PF  20.0   6-10       Kentucky  2239800.0
# Shelvin Mack      8.0       PG  26.0    6-3         Butler  2433333.0
# Jeff Withey      24.0        C  26.0    7-0         Kansas   947276.0
#
# [364 rows x 6 columns]

# %%
# the nan Value is dropped 
# next step is to find out the data type of weight column
before = type(data)
before
# Out:
# pandas.core.frame.DataFrame

# %%
print(before)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# will throws numpy.float64 and numpy.int64
# checking deleting and missing values
data.isna()
# Out:
#                Number  Position    Age  Height  College  Salary
# Name
# Avery Bradley   False     False  False   False    False   False
# Jae Crowder     False     False  False   False    False   False
# R.J. Hunter     False     False  False   False    False   False
# Jordan Mickey   False     False  False   False    False   False
# Kelly Olynyk    False     False  False   False    False   False
# ...               ...       ...    ...     ...      ...     ...
# Rodney Hood     False     False  False   False    False   False
# Chris Johnson   False     False  False   False    False   False
# Trey Lyles      False     False  False   False    False   False
# Shelvin Mack    False     False  False   False    False   False
# Jeff Withey     False     False  False   False    False   False
#
# [364 rows x 6 columns]

# %%
data.isnull()
# Out:
#                Number  Position    Age  Height  College  Salary
# Name
# Avery Bradley   False     False  False   False    False   False
# Jae Crowder     False     False  False   False    False   False
# R.J. Hunter     False     False  False   False    False   False
# Jordan Mickey   False     False  False   False    False   False
# Kelly Olynyk    False     False  False   False    False   False
# ...               ...       ...    ...     ...      ...     ...
# Rodney Hood     False     False  False   False    False   False
# Chris Johnson   False     False  False   False    False   False
# Trey Lyles      False     False  False   False    False   False
# Shelvin Mack    False     False  False   False    False   False
# Jeff Withey     False     False  False   False    False   False
#
# [364 rows x 6 columns]

# %% [markdown]
# # iterating over rows and columns in Dataframe
#
#
# Iteration is a general term for taking each item of something, one after another. Pandas DataFrame consists of rows and columns so, in order to iterate over dataframe, we have to iterate a dataframe like a dictionary. In a dictionary, we iterate over the keys of the object in the same way we have to iterate in dataframe.
#
#     int this we use iterrows() function to get the data into loops

# %%
for i in data.iterrows():
    print(i)
    print("")
# Out:
# ('Avery Bradley', Number                0
# Position             PG
# Age                  25
# Height              6-2
# College           Texas
# Salary      7.73034e+06
# Name: Avery Bradley, dtype: object)
#
# ('Jae Crowder', Number               99
# Position             SF
# Age                  25
# Height              6-6
# College       Marquette
# Salary      6.79612e+06
# Name: Jae Crowder, dtype: object)
#
# ('R.J. Hunter', Number                 28
# Position               SG
# Age                    22
# Height                6-5
# College     Georgia State
# Salary        1.14864e+06
# Name: R.J. Hunter, dtype: object)
#
# ('Jordan Mickey', Number               55
# Position             PF
# Age                  21
# Height              6-8
# College             LSU
# Salary      1.17096e+06
# Name: Jordan Mickey, dtype: object)
#
# ('Kelly Olynyk', Number               41
# Position              C
# Age                  25
# Height              7-0
# ...

# %%
for i in data.itertuples():
    print(i)
    print("")
# Out:
# Pandas(Index='Avery Bradley', Number=0.0, Position='PG', Age=25.0, Height='6-2', College='Texas', Salary=7730337.0)
#
# Pandas(Index='Jae Crowder', Number=99.0, Position='SF', Age=25.0, Height='6-6', College='Marquette', Salary=6796117.0)
#
# Pandas(Index='R.J. Hunter', Number=28.0, Position='SG', Age=22.0, Height='6-5', College='Georgia State', Salary=1148640.0)
#
# Pandas(Index='Jordan Mickey', Number=55.0, Position='PF', Age=21.0, Height='6-8', College='LSU', Salary=1170960.0)
#
# Pandas(Index='Kelly Olynyk', Number=41.0, Position='C', Age=25.0, Height='7-0', College='Gonzaga', Salary=2165160.0)
#
# Pandas(Index='Terry Rozier', Number=12.0, Position='PG', Age=22.0, Height='6-2', College='Louisville', Salary=1824360.0)
#
# Pandas(Index='Marcus Smart', Number=36.0, Position='PG', Age=22.0, Height='6-4', College='Oklahoma State', Salary=3431040.0)
#
# Pandas(Index='Jared Sullinger', Number=7.0, Position='C', Age=24.0, Height='6-9', College='Ohio State', Salary=2569260.0)
#
# ...

# %%
for i in data.iteritems():
    print(i)
    print('')
# Out:
# ('Number', Name
# Avery Bradley     0.0
# Jae Crowder      99.0
# R.J. Hunter      28.0
# Jordan Mickey    55.0
# Kelly Olynyk     41.0
#                  ...
# Rodney Hood       5.0
# Chris Johnson    23.0
# Trey Lyles       41.0
# Shelvin Mack      8.0
# Jeff Withey      24.0
# Name: Number, Length: 364, dtype: float64)
#
# ('Position', Name
# Avery Bradley    PG
# Jae Crowder      SF
# R.J. Hunter      SG
# Jordan Mickey    PF
# Kelly Olynyk      C
#                  ..
# Rodney Hood      SG
# Chris Johnson    SF
# Trey Lyles       PF
# Shelvin Mack     PG
# Jeff Withey       C
# Name: Position, Length: 364, dtype: object)
#
# ('Age', Name
# Avery Bradley    25.0
# Jae Crowder      25.0
# R.J. Hunter      22.0
# Jordan Mickey    21.0
# Kelly Olynyk     25.0
#                  ...
# Rodney Hood      23.0
# Chris Johnson    26.0
# Trey Lyles       20.0
# Shelvin Mack     26.0
# Jeff Withey      26.0
# Name: Age, Length: 364, dtype: float64)
#
# ('Height', Name
# ...

# %% [markdown]
# # working with missing data in pandas
#
# missing Data can occur when no information is provided for one more
# items or for a whole unit. Missing Data is a very big problem in ral life
# scenario
# 1. it's also refer as Na(Not Avail) values in pandas.
# 2. every Data Scientist has to closely look into this section so the damage can prevent in future
# For Example, Suppose different user being surveyed may choose not to share their income, some user may choose not
# to share the address in this way many datasets went missing.

# %%
in pandas treat none and NaN as essentially interchangeable 
for indicating missing or null values.
To facilitate this convention, there are several useful functions for detecting,
removing, and replacing null values in Pandas DataFrame :
    
1.isnull()
2.notnull()
3.dropna()
4.fillna()
5.replace()
6.interpolate()

i am trying with my data

# %%
# chekcing null value
data.isnull()
# Out:
#                Number  Position    Age  Height  College  Salary
# Name
# Avery Bradley   False     False  False   False    False   False
# Jae Crowder     False     False  False   False    False   False
# R.J. Hunter     False     False  False   False    False   False
# Jordan Mickey   False     False  False   False    False   False
# Kelly Olynyk    False     False  False   False    False   False
# ...               ...       ...    ...     ...      ...     ...
# Rodney Hood     False     False  False   False    False   False
# Chris Johnson   False     False  False   False    False   False
# Trey Lyles      False     False  False   False    False   False
# Shelvin Mack    False     False  False   False    False   False
# Jeff Withey     False     False  False   False    False   False
#
# [364 rows x 6 columns]

# %%
# The  rest is topic is on another notebook
